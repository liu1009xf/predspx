# %% [markdown]
# # Predict Range of Daily Price Movement on S&P500 Index Using Vix

# %% [markdown]
# ## Background

# %% [markdown]
# The purpose of his project is tring to find if there are any way that the <span style="color:blue"> Range of Daily Price Change  on S&P500 Index </span> can be predicted by <span style="color:blue"> some form of munipulated data generated from Vix price </span>.
#
#
# VIX is the ticker symbol and the popular name for the Chicago Board Options Exchange's CBOE Volatility Index, a popular measure of the stock market's expectation of volatility based on S&P 500 index options. It is calculated and disseminated on a real-time basis by the CBOE. The VIX is a 30-day expectation of volatility given by a weighted portfolio of out-of-the-money European options on the S&P 500. The formular is as follows:

# %% [markdown]
# <div align="center">
#     $$VIX = \sqrt{\frac{2e^{r\tau}}{\tau}\Big(\int_{0}^{F}{\frac{P(K)}{K^{2}}}dK + \int_{0}^{\infty}{\frac{C(K)}{K^{2}}}dK\Big)}$$
# </div>

# %% [markdown]
# Refer to [\[1\]](https://en.wikipedia.org/wiki/VIX) for more details;

# %% [markdown]
# ## Goal
#
# The final goal of this project is find the optimum model to predict the price range, but a compromise can be made if a given model can predict if the <span style="color:blue">percentage change from open price is less than x% </span> can be predited with a <span style="color:blue">higher probability</span> than those try to predicts size of the range. We also want to gain some insights if possible on predicting daily direction of S&P500.
#
# We will use the following methods(models) to try to find a way to predict the daily S&P500 price range using vix. The following is a list of methods and data sets will be used to construct such a model.

# %% [markdown]
# ## Hypothesis
#
# ### 1: Logistic Regression Can Be Used to Predict If The Price Movement Will Be Within a Pre-set range $\pm x$ ?
# Logistic regression is a statistical model uses a logistic function to model a binary dependent variable. In this case the binary dependent variable is defined as if the price moved more than $x$ no matter in which direction.  If possible we also want to find if there are any relasionships between vix and the diraction of SPX movement.

# %%
import pandas as pd
from datetime import datetime
import utility as utl
import numpy as np
import talib

vix = pd.read_csv("vix.csv")
vix = utl.clean_up_data(vix, "Vix")

snp = pd.read_csv("snp.csv")
snp = utl.clean_up_data(snp, "SPX")

data_set = pd.concat([vix, snp], axis= 1)
data_set = data_set[data_set.index.map(lambda x: x > datetime(2006,1,1) and x < datetime(2021,2,22) )]
data_set["Vix_Prev_Close"] = data_set["Vix_Close"].shift(1)
data_set["Vix_OC_Gap"] = data_set["Vix_Open"] - data_set["Vix_Prev_Close"]
data_set["SPX_Mov"] = data_set["SPX_Open"] - data_set["SPX_Close"]
for i in range(3):
    data_set[f"SPX_Close_shift_{i+1}"] = data_set["SPX_Close"].shift(i+1)

open = data_set['SPX_Open'].dropna()
close = data_set['SPX_Close'].dropna()
high = data_set['SPX_High'].dropna()
low = data_set['SPX_Low'].dropna()

vix_close = data_set['SPX_Close'].dropna()
vix_high = data_set['SPX_High'].dropna()
vix_low = data_set['SPX_Low'].dropna()
data_set["RSI"] = talib.RSI(close, timeperiod=14)
data_set["RSI"] = data_set["RSI"].shift(1)
data_set["ATR"] = talib.ATR(high, low, close, timeperiod = 5)
data_set["ATR"] = data_set["ATR"].shift(1)
data_set["BB_UPPER"], data_set["BB_MID"], data_set["BB_LOWER"] = talib.BBANDS(close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=talib.MA_Type.T3)
data_set["BB_UPPER"].shift(1)
data_set["BB_MID"].shift(1)
data_set["BB_LOWER"].shift(1)
data_set["ADX"] = talib.ADX(high=high,low=low,close=close,timeperiod=10)
data_set["ADX"] = data_set["ADX"].shift(1)

data_set["DOJI"] = talib.CDLDOJI(open,high,low,close)
data_set["DOJI"] = data_set["DOJI"].shift(1)

data_set["VIX_RSI"] = talib.RSI(vix_close, timeperiod=14)
data_set["VIX_RSI"] = data_set["VIX_RSI"].shift(1)
data_set["VIX_ATR"] = talib.ATR(vix_high, vix_low, vix_close, timeperiod = 5)
data_set["VIX_ATR"] = data_set["VIX_ATR"].shift(1)

data_set["SPX_OC_Gap"] = data_set["SPX_Open"] - data_set["SPX_Close_shift_1"]
data_set["SPX_pre_Mov"] = data_set["SPX_Mov"].shift(1)
data_set["SPX_High_shift_1"] = data_set["SPX_High"].shift(1)
data_set["SPX_Low_shift_1"] = data_set["SPX_Low"].shift(1)
data_set["SPX_PRE_HL_RANGE"] = data_set["SPX_High_shift_1"] - data_set["SPX_Low_shift_1"]
data_set["SPX_ABS_Mov"] = abs(data_set["SPX_Mov"] )
data_set["SPX_Direction"] = data_set["SPX_Mov"] >= 0
data_set["SPX_MOV_Direction"] = data_set["SPX_Direction"].apply(lambda x: 1 if x else -1)

data_set["MONTH"] = data_set.index.map(lambda x: x.month)
data_set["DAY"] = data_set.index.map(lambda x: x.day)
data_set["WEEKDAY"] = data_set.index.map(lambda x: x.weekday())

data_set["SPX_MOVE_GT"] = data_set["SPX_ABS_Mov"]>15
data_set["SPX_MOVE_GT_15"] = data_set["SPX_MOVE_GT"].apply(lambda x: 1 if x else 0)


del data_set["SPX_MOVE_GT"]
del data_set["SPX_Direction"]
del data_set["SPX_Mov"]

data_set
# Out:
#             Vix_Close  Vix_Open  Vix_High  Vix_Low  SPX_Close  SPX_Open  \
# Date
# 2006-01-03      11.14     12.25     12.51    10.99        NaN       NaN
# 2006-01-04      11.37     11.22     11.71    10.97    1273.46   1268.80
# 2006-01-05      11.31     11.43     11.84    11.31    1273.48   1273.46
# 2006-01-06      11.00     11.23     11.50    10.81    1285.45   1273.48
# 2006-01-09      11.13     11.35     11.35    10.98    1290.15   1285.45
# ...               ...       ...       ...      ...        ...       ...
# 2021-02-12      19.97     21.60     22.45    19.95    3934.83   3911.65
# 2021-02-16      21.46     21.13     22.46    20.88    3932.59   3939.61
# 2021-02-17      21.50     22.02     23.44    21.09    3931.33   3918.50
# 2021-02-18      22.49     21.98     24.23    21.80    3913.97   3915.86
# 2021-02-19      22.05     23.10     23.19    20.84    3906.71   3921.16
#
#             SPX_High  SPX_Low  Vix_Prev_Close  Vix_OC_Gap  ...  SPX_pre_Mov  \
# Date                                                       ...
# 2006-01-03       NaN      NaN             NaN         NaN  ...          NaN
# 2006-01-04   1275.37  1267.74           11.14        0.08  ...          NaN
# 2006-01-05   1276.91  1270.30           11.37        0.06  ...        -4.66
# 2006-01-06   1286.09  1273.48           11.31       -0.08  ...        -0.02
# 2006-01-09   1290.78  1284.82           11.00        0.35  ...       -11.97
# ...              ...      ...             ...         ...  ...          ...
# 2021-02-12   3937.23  3905.78           21.25        0.35  ...         0.02
# 2021-02-16   3950.43  3923.85           19.97        1.16  ...       -23.18
# 2021-02-17   3933.61  3900.43           21.46        0.56  ...         7.02
# 2021-02-18   3921.98  3885.03           21.50        0.48  ...       -12.83
# 2021-02-19   3930.41  3903.07           22.49        0.61  ...         1.89
#
#             SPX_High_shift_1  SPX_Low_shift_1  SPX_PRE_HL_RANGE  SPX_ABS_Mov  \
# Date
# 2006-01-03               NaN              NaN               NaN          NaN
# 2006-01-04               NaN              NaN               NaN         4.66
# 2006-01-05           1275.37          1267.74              7.63         0.02
# 2006-01-06           1276.91          1270.30              6.61        11.97
# 2006-01-09           1286.09          1273.48             12.61         4.70
# ...                      ...              ...               ...          ...
# 2021-02-12           3925.99          3890.39             35.60        23.18
# 2021-02-16           3937.23          3905.78             31.45         7.02
# 2021-02-17           3950.43          3923.85             26.58        12.83
# 2021-02-18           3933.61          3900.43             33.18         1.89
# 2021-02-19           3921.98          3885.03             36.95        14.45
#
#             SPX_MOV_Direction  MONTH  DAY  WEEKDAY  SPX_MOVE_GT_15
# Date
# 2006-01-03                 -1      1    3        1               0
# 2006-01-04                 -1      1    4        2               0
# 2006-01-05                 -1      1    5        3               0
# 2006-01-06                 -1      1    6        4               0
# 2006-01-09                 -1      1    9        0               0
# ...                       ...    ...  ...      ...             ...
# 2021-02-12                 -1      2   12        4               1
# 2021-02-16                  1      2   16        1               0
# 2021-02-17                 -1      2   17        2               0
# 2021-02-18                  1      2   18        3               0
# 2021-02-19                  1      2   19        4               0
#
# [3813 rows x 33 columns]

# %% [markdown]
# After we clean up the data, we split the above data set into train set and test set with the cut-off of 01/01/2019.

# %%
from sklearn import metrics 
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
training_set = data_set[data_set.index < datetime(2020,1,1)].dropna()
test_set = data_set[data_set.index >= datetime(2020,1,1)].dropna()

logistic_regression = LogisticRegression()
# x_columns = ["SPX_Open", "Vix_OC_Gap", "SPX_pre_Mov", "SPX_OC_Gap", "SPX_High_shift_1", "SPX_Low_shift_1", "RSI", "ATR", "BB_UPPER", "BB_MID", "BB_LOWER", "VIX_RSI", "VIX_ATR"]
# x_columns = ["Vix_OC_Gap", "SPX_pre_Mov", "SPX_PRE_HL_RANGE","SPX_OC_Gap", "RSI", "ATR", "BB_UPPER", "BB_MID", "BB_LOWER", "VIX_RSI", "VIX_ATR"]

x_columns = ["Vix_OC_Gap", "SPX_pre_Mov", "SPX_PRE_HL_RANGE","SPX_OC_Gap", "RSI", "ATR", "ADX","BB_UPPER", "BB_MID", "BB_LOWER", "VIX_RSI", "VIX_ATR", "MONTH", "DAY","WEEKDAY"]
for i in range(3):
    x_columns.append(f"SPX_Close_shift_{i+1}")

x_train = training_set.loc[:, x_columns]
x_test = test_set.loc[:, x_columns]
clf = logistic_regression.fit(x_train, training_set["SPX_MOVE_GT_15"])
y_pred = logistic_regression.predict(x_test)
accuracy = metrics.accuracy_score(test_set["SPX_MOVE_GT_15"], y_pred)
accuracy_percentage = 100 * accuracy

test_set["range_predict"] = y_pred
accuracy_percentage
pd.set_option('display.max_rows', 10)
test_set[test_set["range_predict"] != test_set["SPX_MOVE_GT_15"]]
test_set[(test_set["range_predict"] == 0) & (test_set["SPX_MOVE_GT_15"] == 1)]

# test_set[test_set["SPX_MOVE_GT_15"]==1]

# len(test_set[(test_set["range_predict"] == 0) & (test_set["SPX_MOVE_GT_15"] == 1)])/len(test_set[test_set["SPX_MOVE_GT_15"]==1])
# accuracy_percentage
# x_train
# Out:
#             Vix_Close  Vix_Open  Vix_High  Vix_Low  SPX_Close  SPX_Open  \
# Date
# 2020-01-06      13.85     15.45     16.39    13.54    3246.28   3217.55
# 2020-01-10      12.56     12.42     12.87    12.09    3265.35   3281.81
# 2020-01-13      12.32     12.84     13.09    12.32    3288.13   3271.13
# 2020-01-24      14.56     12.75     15.98    12.62    3295.47   3333.10
# 2020-01-29      16.39     15.68     16.65    14.94    3273.40   3289.46
# ...               ...       ...       ...      ...        ...       ...
# 2021-01-14      23.25     22.22     23.47    21.66    3795.54   3814.98
# 2021-01-15      24.34     23.52     25.80    23.08    3768.25   3788.73
# 2021-01-19      23.24     23.03     23.56    22.53    3798.91   3781.88
# 2021-01-20      21.58     22.82     22.86    21.37    3851.85   3816.22
# 2021-02-12      19.97     21.60     22.45    19.95    3934.83   3911.65
#
#             SPX_High  SPX_Low  Vix_Prev_Close  Vix_OC_Gap  ...  \
# Date                                                       ...
# 2020-01-06   3246.84  3214.64           14.02        1.43  ...
# 2020-01-10   3282.99  3260.86           12.54       -0.12  ...
# 2020-01-13   3288.13  3268.43           12.56        0.28  ...
# 2020-01-24   3333.18  3281.53           12.98       -0.23  ...
# 2020-01-29   3293.47  3271.89           16.28       -0.60  ...
# ...              ...      ...             ...         ...  ...
# 2021-01-14   3823.60  3792.86           22.21        0.01  ...
# 2021-01-15   3788.73  3749.62           23.25        0.27  ...
# 2021-01-19   3804.53  3780.37           24.34       -1.31  ...
# 2021-01-20   3859.75  3816.22           23.24       -0.42  ...
# 2021-02-12   3937.23  3905.78           21.25        0.35  ...
#
#             SPX_High_shift_1  SPX_Low_shift_1  SPX_PRE_HL_RANGE  SPX_ABS_Mov  \
# Date
# 2020-01-06           3246.15          3222.34             23.81        28.73
# 2020-01-10           3275.58          3263.67             11.91        16.46
# 2020-01-13           3282.99          3260.86             22.13        17.00
# 2020-01-24           3326.88          3301.87             25.01        37.63
# 2020-01-29           3285.78          3253.22             32.56        16.06
# ...                      ...              ...               ...          ...
# 2021-01-14           3820.96          3791.50             29.46        19.44
# 2021-01-15           3823.60          3792.86             30.74        20.48
# 2021-01-19           3788.73          3749.62             39.11        17.03
# 2021-01-20           3804.53          3780.37             24.16        35.63
# 2021-02-12           3925.99          3890.39             35.60        23.18
#
#             SPX_MOV_Direction  MONTH  DAY  WEEKDAY  SPX_MOVE_GT_15  \
# Date
# 2020-01-06                 -1      1    6        0               1
# 2020-01-10                  1      1   10        4               1
# 2020-01-13                 -1      1   13        0               1
# 2020-01-24                  1      1   24        4               1
# 2020-01-29                  1      1   29        2               1
# ...                       ...    ...  ...      ...             ...
# 2021-01-14                  1      1   14        3               1
# 2021-01-15                  1      1   15        4               1
# 2021-01-19                 -1      1   19        1               1
# 2021-01-20                 -1      1   20        2               1
# 2021-02-12                 -1      2   12        4               1
#
#             range_predict
# Date
# 2020-01-06              0
# 2020-01-10              0
# 2020-01-13              0
# 2020-01-24              0
# 2020-01-29              0
# ...                   ...
# 2021-01-14              0
# 2021-01-15              0
# 2021-01-19              0
# 2021-01-20              0
# 2021-02-12              0
#
# [60 rows x 34 columns]

# %% [markdown]
# we can see from the above simple logistic regression, we only get a 43 percent of accuracy, which is not good enough. What we want to try before we try to switch to other models , we can try to add more dependent variables. We first try some technical indicators try take some properties of historical datas into account.

# %% [markdown]
# We will try ann next

# %%
import tensorflow as tf

ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units= 30, activation='relu'))
ann.add(tf.keras.layers.Dense(units= 60, activation='relu'))
ann.add(tf.keras.layers.Dense(units= 30, activation='relu'))
ann.add(tf.keras.layers.Dense(units= 1, activation='sigmoid'))

ann.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

ann.fit(x_train, training_set["SPX_MOVE_GT_15"], batch_size = 32, epochs = 150)
result = ann.predict(x_test)
# Out:
# Epoch 1/150
# 110/110 [==============================] - 1s 763us/step - loss: 9.5058 - accuracy: 0.6340
# Epoch 2/150
# 110/110 [==============================] - 0s 707us/step - loss: 0.9781 - accuracy: 0.6732
# Epoch 3/150
# 110/110 [==============================] - 0s 858us/step - loss: 1.1385 - accuracy: 0.6388
# Epoch 4/150
# 110/110 [==============================] - 0s 819us/step - loss: 0.6391 - accuracy: 0.7250
# Epoch 5/150
# 110/110 [==============================] - 0s 839us/step - loss: 1.0281 - accuracy: 0.7213
# Epoch 6/150
# 110/110 [==============================] - 0s 824us/step - loss: 0.7002 - accuracy: 0.7281
# Epoch 7/150
# 110/110 [==============================] - 0s 891us/step - loss: 0.6520 - accuracy: 0.7182
# Epoch 8/150
# 110/110 [==============================] - 0s 810us/step - loss: 0.6489 - accuracy: 0.7327
# Epoch 9/150
# 110/110 [==============================] - 0s 800us/step - loss: 0.6603 - accuracy: 0.7335
# Epoch 10/150
# 110/110 [==============================] - 0s 758us/step - loss: 0.6567 - accuracy: 0.7481
# Epoch 11/150
# 110/110 [==============================] - 0s 753us/step - loss: 0.8607 - accuracy: 0.7430
# Epoch 12/150
# 110/110 [==============================] - 0s 811us/step - loss: 0.7935 - accuracy: 0.6874
# Epoch 13/150
# 110/110 [==============================] - 0s 745us/step - loss: 0.5493 - accuracy: 0.7570
# Epoch 14/150
# 110/110 [==============================] - 0s 718us/step - loss: 0.5515 - accuracy: 0.7434
# Epoch 15/150
# 110/110 [==============================] - 0s 758us/step - loss: 0.5723 - accuracy: 0.7542
# Epoch 16/150
# 110/110 [==============================] - 0s 825us/step - loss: 0.6858 - accuracy: 0.7160
# Epoch 17/150
# 110/110 [==============================] - 0s 717us/step - loss: 0.5739 - accuracy: 0.7541
# Epoch 18/150
# 110/110 [==============================] - 0s 720us/step - loss: 0.9298 - accuracy: 0.7016
# Epoch 19/150
# 110/110 [==============================] - 0s 700us/step - loss: 0.6221 - accuracy: 0.7567
# Epoch 20/150
# 110/110 [==============================] - 0s 720us/step - loss: 0.5200 - accuracy: 0.7689
# Epoch 21/150
# 110/110 [==============================] - 0s 738us/step - loss: 0.5488 - accuracy: 0.7702
# Epoch 22/150
# 110/110 [==============================] - 0s 802us/step - loss: 0.6124 - accuracy: 0.7363
# Epoch 23/150
# 110/110 [==============================] - 0s 798us/step - loss: 0.5420 - accuracy: 0.7685
# Epoch 24/150
# 110/110 [==============================] - 0s 821us/step - loss: 0.6450 - accuracy: 0.7259
# Epoch 25/150
# 110/110 [==============================] - 0s 869us/step - loss: 0.5886 - accuracy: 0.7577
# Epoch 26/150
# 110/110 [==============================] - 0s 724us/step - loss: 0.6402 - accuracy: 0.7260
# Epoch 27/150
# 110/110 [==============================] - 0s 744us/step - loss: 0.5184 - accuracy: 0.7592
# Epoch 28/150
# 110/110 [==============================] - 0s 800us/step - loss: 0.5918 - accuracy: 0.7620
# Epoch 29/150
# 110/110 [==============================] - 0s 735us/step - loss: 0.6784 - accuracy: 0.7363
# Epoch 30/150
# 110/110 [==============================] - 0s 783us/step - loss: 0.4747 - accuracy: 0.7763
# Epoch 31/150
# 110/110 [==============================] - 0s 817us/step - loss: 0.5476 - accuracy: 0.7504
# Epoch 32/150
# 110/110 [==============================] - 0s 744us/step - loss: 0.5554 - accuracy: 0.7653
# Epoch 33/150
# 110/110 [==============================] - 0s 746us/step - loss: 0.5085 - accuracy: 0.7654
# Epoch 34/150
# 110/110 [==============================] - 0s 722us/step - loss: 0.5480 - accuracy: 0.7570
# Epoch 35/150
# 110/110 [==============================] - 0s 737us/step - loss: 0.4971 - accuracy: 0.7692
# Epoch 36/150
# 110/110 [==============================] - 0s 841us/step - loss: 0.5128 - accuracy: 0.7754
# Epoch 37/150
# 110/110 [==============================] - 0s 915us/step - loss: 0.4921 - accuracy: 0.7683
# Epoch 38/150
# 110/110 [==============================] - 0s 806us/step - loss: 0.5356 - accuracy: 0.7546
# Epoch 39/150
# 110/110 [==============================] - 0s 786us/step - loss: 0.5378 - accuracy: 0.7686
# Epoch 40/150
# 110/110 [==============================] - 0s 859us/step - loss: 0.5384 - accuracy: 0.7533
# Epoch 41/150
# 110/110 [==============================] - 0s 880us/step - loss: 0.5066 - accuracy: 0.7813
# Epoch 42/150
# 110/110 [==============================] - 0s 861us/step - loss: 0.4997 - accuracy: 0.7673
# Epoch 43/150
# 110/110 [==============================] - 0s 822us/step - loss: 0.5370 - accuracy: 0.7511
# Epoch 44/150
# 110/110 [==============================] - 0s 812us/step - loss: 0.4999 - accuracy: 0.7705
# Epoch 45/150
# 110/110 [==============================] - 0s 832us/step - loss: 0.4981 - accuracy: 0.7652
# Epoch 46/150
# 110/110 [==============================] - 0s 767us/step - loss: 0.5106 - accuracy: 0.7572
# Epoch 47/150
# 110/110 [==============================] - 0s 880us/step - loss: 0.5039 - accuracy: 0.7596
# Epoch 48/150
# 110/110 [==============================] - 0s 747us/step - loss: 0.4770 - accuracy: 0.7826
# Epoch 49/150
# 110/110 [==============================] - 0s 840us/step - loss: 0.5002 - accuracy: 0.7660
# Epoch 50/150
# 110/110 [==============================] - 0s 746us/step - loss: 0.4845 - accuracy: 0.7737
# Epoch 51/150
# 110/110 [==============================] - 0s 878us/step - loss: 0.4849 - accuracy: 0.7633
# Epoch 52/150
# 110/110 [==============================] - 0s 731us/step - loss: 0.5338 - accuracy: 0.7549
# Epoch 53/150
# 110/110 [==============================] - 0s 765us/step - loss: 0.4761 - accuracy: 0.7770
# Epoch 54/150
# 110/110 [==============================] - 0s 739us/step - loss: 0.4916 - accuracy: 0.7784
# Epoch 55/150
# 110/110 [==============================] - 0s 787us/step - loss: 0.4820 - accuracy: 0.7729
# Epoch 56/150
# 110/110 [==============================] - 0s 844us/step - loss: 0.4640 - accuracy: 0.7833
# Epoch 57/150
# 110/110 [==============================] - 0s 851us/step - loss: 0.5117 - accuracy: 0.7708
# Epoch 58/150
# 110/110 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 0.7782
# Epoch 59/150
# 110/110 [==============================] - 0s 833us/step - loss: 0.5061 - accuracy: 0.7711
# Epoch 60/150
# 110/110 [==============================] - 0s 746us/step - loss: 0.4760 - accuracy: 0.7760
# Epoch 61/150
# 110/110 [==============================] - 0s 907us/step - loss: 0.5392 - accuracy: 0.7566
# Epoch 62/150
# 110/110 [==============================] - 0s 884us/step - loss: 0.4809 - accuracy: 0.7683
# Epoch 63/150
# 110/110 [==============================] - 0s 858us/step - loss: 0.5231 - accuracy: 0.7593
# Epoch 64/150
# 110/110 [==============================] - 0s 812us/step - loss: 0.4839 - accuracy: 0.7786
# Epoch 65/150
# 110/110 [==============================] - 0s 828us/step - loss: 0.4987 - accuracy: 0.7673
# Epoch 66/150
# 110/110 [==============================] - 0s 834us/step - loss: 0.4767 - accuracy: 0.7784
# Epoch 67/150
# 110/110 [==============================] - 0s 822us/step - loss: 0.4950 - accuracy: 0.7737
# Epoch 68/150
# 110/110 [==============================] - 0s 812us/step - loss: 0.4935 - accuracy: 0.7715
# Epoch 69/150
# 110/110 [==============================] - 0s 764us/step - loss: 0.4790 - accuracy: 0.7720
# Epoch 70/150
# 110/110 [==============================] - 0s 799us/step - loss: 0.4913 - accuracy: 0.7677
# Epoch 71/150
# 110/110 [==============================] - 0s 896us/step - loss: 0.4730 - accuracy: 0.7720
# Epoch 72/150
# 110/110 [==============================] - 0s 910us/step - loss: 0.4719 - accuracy: 0.7706
# Epoch 73/150
# 110/110 [==============================] - 0s 887us/step - loss: 0.4741 - accuracy: 0.7790
# Epoch 74/150
# 110/110 [==============================] - 0s 803us/step - loss: 0.4787 - accuracy: 0.7735
# Epoch 75/150
# 110/110 [==============================] - 0s 788us/step - loss: 0.4741 - accuracy: 0.7832
# Epoch 76/150
# 110/110 [==============================] - 0s 839us/step - loss: 0.5291 - accuracy: 0.7426
# Epoch 77/150
# 110/110 [==============================] - 0s 824us/step - loss: 0.4647 - accuracy: 0.7836
# Epoch 78/150
# 110/110 [==============================] - 0s 843us/step - loss: 0.5047 - accuracy: 0.7619
# Epoch 79/150
# 110/110 [==============================] - 0s 824us/step - loss: 0.4640 - accuracy: 0.7792
# Epoch 80/150
# 110/110 [==============================] - 0s 796us/step - loss: 0.4931 - accuracy: 0.7787
# Epoch 81/150
# 110/110 [==============================] - 0s 797us/step - loss: 0.4725 - accuracy: 0.7737
# Epoch 82/150
# 110/110 [==============================] - 0s 792us/step - loss: 0.4620 - accuracy: 0.7807
# Epoch 83/150
# 110/110 [==============================] - 0s 819us/step - loss: 0.4860 - accuracy: 0.7674
# Epoch 84/150
# 110/110 [==============================] - 0s 966us/step - loss: 0.4699 - accuracy: 0.7792
# Epoch 85/150
# 110/110 [==============================] - 0s 865us/step - loss: 0.4610 - accuracy: 0.7869
# Epoch 86/150
# 110/110 [==============================] - 0s 846us/step - loss: 0.4427 - accuracy: 0.7918
# Epoch 87/150
# 110/110 [==============================] - 0s 1ms/step - loss: 0.4680 - accuracy: 0.7788
# Epoch 88/150
# 110/110 [==============================] - 0s 907us/step - loss: 0.4718 - accuracy: 0.7757
# Epoch 89/150
# 110/110 [==============================] - 0s 962us/step - loss: 0.4589 - accuracy: 0.7874
# Epoch 90/150
# 110/110 [==============================] - 0s 882us/step - loss: 0.4937 - accuracy: 0.7748
# Epoch 91/150
# 110/110 [==============================] - 0s 895us/step - loss: 0.4670 - accuracy: 0.7788
# Epoch 92/150
# 110/110 [==============================] - 0s 823us/step - loss: 0.4788 - accuracy: 0.7749
# Epoch 93/150
# 110/110 [==============================] - 0s 889us/step - loss: 0.4724 - accuracy: 0.7750
# Epoch 94/150
# 110/110 [==============================] - 0s 1ms/step - loss: 0.4766 - accuracy: 0.7726
# Epoch 95/150
# 110/110 [==============================] - 0s 1ms/step - loss: 0.4658 - accuracy: 0.7744
# Epoch 96/150
# 110/110 [==============================] - 0s 786us/step - loss: 0.4653 - accuracy: 0.7765
# Epoch 97/150
# 110/110 [==============================] - 0s 855us/step - loss: 0.4736 - accuracy: 0.7772
# Epoch 98/150
# 110/110 [==============================] - 0s 798us/step - loss: 0.4683 - accuracy: 0.7790
# Epoch 99/150
# 110/110 [==============================] - 0s 804us/step - loss: 0.4714 - accuracy: 0.7581
# Epoch 100/150
# 110/110 [==============================] - 0s 807us/step - loss: 0.4840 - accuracy: 0.7778
# Epoch 101/150
# 110/110 [==============================] - 0s 823us/step - loss: 0.4891 - accuracy: 0.7723
# Epoch 102/150
# 110/110 [==============================] - 0s 779us/step - loss: 0.5076 - accuracy: 0.7794
# Epoch 103/150
# 110/110 [==============================] - 0s 800us/step - loss: 0.4582 - accuracy: 0.7838
# Epoch 104/150
# 110/110 [==============================] - 0s 797us/step - loss: 0.4970 - accuracy: 0.7709
# Epoch 105/150
# 110/110 [==============================] - 0s 776us/step - loss: 0.5084 - accuracy: 0.7659
# Epoch 106/150
# 110/110 [==============================] - 0s 817us/step - loss: 0.4747 - accuracy: 0.7846
# Epoch 107/150
# 110/110 [==============================] - 0s 843us/step - loss: 0.4670 - accuracy: 0.7752
# Epoch 108/150
# 110/110 [==============================] - 0s 1ms/step - loss: 0.4639 - accuracy: 0.7787
# Epoch 109/150
# 110/110 [==============================] - 0s 805us/step - loss: 0.4707 - accuracy: 0.7766
# Epoch 110/150
# 110/110 [==============================] - 0s 794us/step - loss: 0.4630 - accuracy: 0.7818
# Epoch 111/150
# 110/110 [==============================] - 0s 797us/step - loss: 0.5153 - accuracy: 0.7607
# Epoch 112/150
# 110/110 [==============================] - 0s 795us/step - loss: 0.4763 - accuracy: 0.7805
# Epoch 113/150
# 110/110 [==============================] - 0s 789us/step - loss: 0.4669 - accuracy: 0.7739
# Epoch 114/150
# 110/110 [==============================] - 0s 809us/step - loss: 0.4692 - accuracy: 0.7776
# Epoch 115/150
# 110/110 [==============================] - 0s 773us/step - loss: 0.4907 - accuracy: 0.7694
# Epoch 116/150
# 110/110 [==============================] - 0s 825us/step - loss: 0.4626 - accuracy: 0.7862
# Epoch 117/150
# 110/110 [==============================] - 0s 838us/step - loss: 0.4731 - accuracy: 0.7767
# Epoch 118/150
# 110/110 [==============================] - 0s 846us/step - loss: 0.4853 - accuracy: 0.7704
# Epoch 119/150
# 110/110 [==============================] - 0s 821us/step - loss: 0.4912 - accuracy: 0.7555
# Epoch 120/150
# 110/110 [==============================] - 0s 812us/step - loss: 0.4654 - accuracy: 0.7853
# Epoch 121/150
# 110/110 [==============================] - 0s 801us/step - loss: 0.4751 - accuracy: 0.7687
# Epoch 122/150
# 110/110 [==============================] - 0s 819us/step - loss: 0.4621 - accuracy: 0.7736
# Epoch 123/150
# 110/110 [==============================] - 0s 790us/step - loss: 0.4627 - accuracy: 0.7862
# Epoch 124/150
# 110/110 [==============================] - 0s 804us/step - loss: 0.4922 - accuracy: 0.7750
# Epoch 125/150
# 110/110 [==============================] - 0s 802us/step - loss: 0.4878 - accuracy: 0.7657
# Epoch 126/150
# 110/110 [==============================] - 0s 789us/step - loss: 0.4675 - accuracy: 0.7831
# Epoch 127/150
# 110/110 [==============================] - 0s 812us/step - loss: 0.4819 - accuracy: 0.7695
# Epoch 128/150
# 110/110 [==============================] - 0s 794us/step - loss: 0.4630 - accuracy: 0.7717
# Epoch 129/150
# 110/110 [==============================] - 0s 807us/step - loss: 0.4762 - accuracy: 0.7815
# Epoch 130/150
# 110/110 [==============================] - 0s 850us/step - loss: 0.4552 - accuracy: 0.7741
# Epoch 131/150
# 110/110 [==============================] - 0s 821us/step - loss: 0.4659 - accuracy: 0.7705
# Epoch 132/150
# 110/110 [==============================] - 0s 850us/step - loss: 0.4757 - accuracy: 0.7747
# Epoch 133/150
# 110/110 [==============================] - 0s 817us/step - loss: 0.4630 - accuracy: 0.7785
# Epoch 134/150
# 110/110 [==============================] - 0s 821us/step - loss: 0.4834 - accuracy: 0.7650
# Epoch 135/150
# 110/110 [==============================] - 0s 792us/step - loss: 0.4697 - accuracy: 0.7807
# Epoch 136/150
# 110/110 [==============================] - 0s 803us/step - loss: 0.4681 - accuracy: 0.7699
# Epoch 137/150
# 110/110 [==============================] - 0s 822us/step - loss: 0.4540 - accuracy: 0.7857
# Epoch 138/150
# 110/110 [==============================] - 0s 817us/step - loss: 0.4890 - accuracy: 0.7721
# Epoch 139/150
# 110/110 [==============================] - 0s 843us/step - loss: 0.4947 - accuracy: 0.7783
# Epoch 140/150
# 110/110 [==============================] - 0s 817us/step - loss: 0.4762 - accuracy: 0.7797
# Epoch 141/150
# 110/110 [==============================] - 0s 805us/step - loss: 0.4804 - accuracy: 0.7750
# Epoch 142/150
# 110/110 [==============================] - 0s 875us/step - loss: 0.4635 - accuracy: 0.7747
# Epoch 143/150
# 110/110 [==============================] - 0s 808us/step - loss: 0.4820 - accuracy: 0.7694
# Epoch 144/150
# 110/110 [==============================] - 0s 830us/step - loss: 0.4557 - accuracy: 0.7882
# Epoch 145/150
# 110/110 [==============================] - 0s 775us/step - loss: 0.4810 - accuracy: 0.7773
# Epoch 146/150
# 110/110 [==============================] - 0s 941us/step - loss: 0.4994 - accuracy: 0.7701
# Epoch 147/150
# 110/110 [==============================] - 0s 794us/step - loss: 0.4869 - accuracy: 0.7709
# Epoch 148/150
# 110/110 [==============================] - 0s 788us/step - loss: 0.4623 - accuracy: 0.7866
# Epoch 149/150
# 110/110 [==============================] - 0s 781us/step - loss: 0.4612 - accuracy: 0.7802
# Epoch 150/150
# 110/110 [==============================] - 0s 810us/step - loss: 0.4601 - accuracy: 0.7852

# %%
test_set["ann predict"] = [1 if x>0.5 else 0 for x in result]
test_set[test_set["ann predict"] != test_set["SPX_MOVE_GT_15"]]
# Out:
#             Vix_Close  Vix_Open  Vix_High  Vix_Low  SPX_Close  SPX_Open  \
# Date
# 2020-01-06      13.85     15.45     16.39    13.54    3246.28   3217.55
# 2020-01-10      12.56     12.42     12.87    12.09    3265.35   3281.81
# 2020-01-13      12.32     12.84     13.09    12.32    3288.13   3271.13
# 2020-01-24      14.56     12.75     15.98    12.62    3295.47   3333.10
# 2020-01-27      18.23     17.42     19.02    16.82    3243.63   3247.16
# ...               ...       ...       ...      ...        ...       ...
# 2021-02-03      22.91     24.59     25.43    22.91    3830.17   3840.27
# 2021-02-05      20.87     21.99     22.16    20.86    3886.83   3878.30
# 2021-02-09      21.63     21.57     22.26    20.65    3911.23   3910.49
# 2021-02-10      21.99     21.64     23.85    19.69    3909.88   3920.78
# 2021-02-12      19.97     21.60     22.45    19.95    3934.83   3911.65
#
#             SPX_High  SPX_Low  Vix_Prev_Close  Vix_OC_Gap  ...  \
# Date                                                       ...
# 2020-01-06   3246.84  3214.64           14.02        1.43  ...
# 2020-01-10   3282.99  3260.86           12.54       -0.12  ...
# 2020-01-13   3288.13  3268.43           12.56        0.28  ...
# 2020-01-24   3333.18  3281.53           12.98       -0.23  ...
# 2020-01-27   3258.85  3234.50           14.56        2.86  ...
# ...              ...      ...             ...         ...  ...
# 2021-02-03   3847.51  3816.68           25.56       -0.97  ...
# 2021-02-05   3894.56  3874.93           21.77        0.22  ...
# 2021-02-09   3918.35  3902.64           21.24        0.33  ...
# 2021-02-10   3931.50  3884.94           21.63        0.01  ...
# 2021-02-12   3937.23  3905.78           21.25        0.35  ...
#
#             SPX_Low_shift_1  SPX_PRE_HL_RANGE  SPX_ABS_Mov  SPX_MOV_Direction  \
# Date
# 2020-01-06          3222.34             23.81        28.73                 -1
# 2020-01-10          3263.67             11.91        16.46                  1
# 2020-01-13          3260.86             22.13        17.00                 -1
# 2020-01-24          3301.87             25.01        37.63                  1
# 2020-01-27          3281.53             51.65         3.53                  1
# ...                     ...               ...          ...                ...
# 2021-02-03          3791.84             51.25        10.10                  1
# 2021-02-05          3836.66             35.76         8.53                 -1
# 2021-02-09          3892.59             23.18         0.74                 -1
# 2021-02-10          3902.64             15.71        10.90                  1
# 2021-02-12          3890.39             35.60        23.18                 -1
#
#             MONTH  DAY  WEEKDAY  SPX_MOVE_GT_15  range_predict  ann predict
# Date
# 2020-01-06      1    6        0               1              0            0
# 2020-01-10      1   10        4               1              0            0
# 2020-01-13      1   13        0               1              0            0
# 2020-01-24      1   24        4               1              0            0
# 2020-01-27      1   27        0               0              1            1
# ...           ...  ...      ...             ...            ...          ...
# 2021-02-03      2    3        2               0              1            1
# 2021-02-05      2    5        4               0              1            1
# 2021-02-09      2    9        1               0              1            1
# 2021-02-10      2   10        2               0              0            1
# 2021-02-12      2   12        4               1              0            0
#
# [87 rows x 35 columns]

# %%
# pd.set_option('display.max_rows', None)
len(test_set[test_set["ann predict"] == 1 ])
test_set[(test_set["ann predict"] == 0) & (test_set["SPX_MOVE_GT_15"] ==1) & (test_set["WEEKDAY"] == 4)]
# acc = metrics.accuracy_score(test_set["SPX_MOVE_GT_15"], test_set["ann predict"])
# acc
# Out:
#             Vix_Close  Vix_Open  Vix_High  Vix_Low  SPX_Close  SPX_Open  \
# Date
# 2020-01-10      12.56     12.42     12.87    12.09    3265.35   3281.81
# 2020-01-24      14.56     12.75     15.98    12.62    3295.47   3333.10
# 2020-02-21      17.08     17.33     18.21    16.19    3337.75   3360.50
# 2021-02-12      19.97     21.60     22.45    19.95    3934.83   3911.65
#
#             SPX_High  SPX_Low  Vix_Prev_Close  Vix_OC_Gap  ...  \
# Date                                                       ...
# 2020-01-10   3282.99  3260.86           12.54       -0.12  ...
# 2020-01-24   3333.18  3281.53           12.98       -0.23  ...
# 2020-02-21   3360.76  3328.45           15.56        1.77  ...
# 2021-02-12   3937.23  3905.78           21.25        0.35  ...
#
#             SPX_Low_shift_1  SPX_PRE_HL_RANGE  SPX_ABS_Mov  SPX_MOV_Direction  \
# Date
# 2020-01-10          3263.67             11.91        16.46                  1
# 2020-01-24          3301.87             25.01        37.63                  1
# 2020-02-21          3341.02             48.13        22.75                  1
# 2021-02-12          3890.39             35.60        23.18                 -1
#
#             MONTH  DAY  WEEKDAY  SPX_MOVE_GT_15  range_predict  ann predict
# Date
# 2020-01-10      1   10        4               1              0            0
# 2020-01-24      1   24        4               1              0            0
# 2020-02-21      2   21        4               1              0            0
# 2021-02-12      2   12        4               1              0            0
#
# [4 rows x 35 columns]
